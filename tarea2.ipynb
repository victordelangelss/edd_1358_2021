# %% [markdown]
# <a href="https://colab.research.google.com/github/victordelangelss/edd_1358_2021/blob/master/tarea2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
Array
"""
class Array:
    def __init__( self, tam ):
        self.__datos = [ 0 for x in range(tam) ] #generador 

    def get_item( self, index ):
        dato  = 0
        if index >= 0 and index < len( self.__datos ): 
            dato = self.__datos[index]
        else:
            print("Error en el indice")
        return dato

    def set_item( self, dato, index):
        if index >= 0 and index < len( self.__datos ): 
            self.__datos[index] = dato
        else:
            print("Error en el indice")

    def get_length( self ):
		#Obtener el tamaño del arreglo
		    return len( self.__datos )
  
    def clear( self , dato ):
        #establece todos los valores del ADT al valor enviado en dato.
		    self.__datos = [dato for x in range(self.__tam)]

    def __iter__( self ):
            return _getIterator(self.__datos)


class _getIterator:
    def __init__( self , arreglo ):
        self.__arreglo = arreglo
        self.__indice_actual = 0

    def __iter__( self ):
        return self

    def __next__( self  ):
        if self.__indice_actual < len(self.__arreglo):
            dato = self.__arreglo[self.__indice_actual]
            self.__indice_actual +=1
            return dato
        else:
            raise StopIteration
    def getIterator( self ):
        return _getIterator( self.__datos )




mi_arreglo = Array(1)
print(mi_arreglo.get_item( 1 ))
mi_arreglo.set_item( 2345 , 3 )
print(mi_arreglo.get_item( 1 ))
# Out:
# Error en el indice
# 0
# Error en el indice
# Error en el indice
# 0

# %%
class Empleado:
    def __init__( self,  num, nom, pat, mat, he, sb, anio, sf ):
        self.__num_trabajador = num
        self.__nombres = nom
        self.__paterno =  pat
        self.__materno =  mat
        self.__horas_extra = he
        self.__sueldo_base = sb
        self.__anio_ingreso  = anio
        self.__sueldo_final = sf
    #get y set
    @property
    def num_trabajador( self ):
        return self.__num_trabajador

    def nombres( self ):
        return self.__nombres

    def paterno( self ):
         return self.__paterno

    def materno( self ):
         return self.__materno

    def horas_extra( self ):
         return self.__horas_extra

    def sueldo_base( self ):
         return self.__sueldo_base

    def anio_ingreso( self ):
         return self.__anio_ingreso


    @num_trabajador.setter
    def num_trabajador( self, num ):
        self.__num_trabajador = num
        
    @nombres.setter
    def nombres( self, nom ):
        self.__nombres = nom

    @paterno.setter
    def paterno( self, pat ):
        self.__paterno = pat

    @materno.setter
    def materno( self, mat ):
        self.__materno = mat

    @horas_extra.setter
    def horas_extra( self, he ):
        self.__horas_extra = he

    @sueldo_base.setter
    def sueldo_base( self, sb ):
        self.__sueldo_base = sb

    @anio_ingres.setter
    def anio_ingreso( self, anio ):
        self.__anio_ingreso = anio

#to_string()
    def to_string( self,  x):
        if x == "num_trabajador":
            return "numumero de trabajador = " + self.__num_trabajador

        elif x == "nombres":
            return "nombres = " + self.__nombres

        elif x == "patderno":
            return "paterno = " + self.__paterno

        elif x == "matderno":
            return "materno = " + self.__materno

        elif x == "horas_extra":
            return "horas extra = " + self.__horas_extra

        elif x == "sueldo_base":
            return "sueldo base = " + self.__sueldo_base

        elif x == "anio_base":
            return "año base = " + self.__anio_ingreso

        else:
            print("no valido")   
    #metodos de uso general : calculos 
    def sueldo_final( self ):
        retur sueldo_base + (horas_extra*276.5) + (2020 - anio_ingreso) * ( sueldo_base*0.03)

# %%
"""
ADT sueldos --> encapsula datos de nómina

cargar_datos ( ruta_archivo )
calcular_sueldos ( )
reportar_mayor_ant ( )
reportar_menor_ant ( )
"""
class Sueldos:
    def __init__( self ):
        self.__data = None

    def cargar_datos( self, ruta_archivo):
        archivo = open( ruta_archivo, "rt", encoding='latin1' )
        lineas = archivo.readlines()
        archivo.close()
        self.__data = Array( len (lineas) -1 )
        # Su tarea
        for lineas in lineas:
            print(lineas)
            # separar campos
            #crear un objeto de
            #cargar ese objeto a self.__data.set_item()
   
    def Empleado( num, nom, pat, mat, he, sb, anio, sf ):


ejemplo = Sueldos()
ejemplo.cargar_datos('junio.dat')
# Out:
# numero de trabajador, nombres, paterno, materno, horas extra, sueldo base, aÃ±o de ingreso
#
# 2345,CARLOS,PEREZ,CASTILLO,0,9850,2017
#
# 5754,ANGEL,GOMEZ,GARRIDO,1,9850,2020
#
# 5345,JESUS,MARTIN,SANTOS,2,9850,2016
#
# 3267,DAVID,JIMENEZ,LOZANO,2,9850,2017
#
# 8765,PEDRO,RUIZ,GUERRERO,2,9850,2017
#
# 5454,DANIEL,HERNANDEZ,CANO,3,9850,2018
#
# 3456,ALEJANDRO,DIAZ,PRIETO,2,9850,2018
#
# 3445,MARIA,MORENO,MENDEZ,1,9850,2018
#
# 9088,ALBERTO,MUOZ,CRUZ,1,9850,2017
#
# 8877,RAFAEL,ALVAREZ,FLORES,2,9850,2017
#
# 6767,FERNANDO,ROMERO,HERRERA,4,9850,2019
#
# 5654,PABLO,ALONSO,GALLEGO,1,9850,2019
#
# 4323,JORGE,GUTIERREZ,MARQUEZ,2,9850,2020
#
# 2232,RAMON,NAVARRO,LEON,1,9850,2016
